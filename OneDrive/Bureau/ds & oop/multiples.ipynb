# %%
import pandas as pd
import matplotlib.pyplot as plt

multiples_df = pd.read_csv('new_white_filters_-_multiples.csv')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #1', y = 'Position (m) Run #1')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #2', y = 'Position (m) Run #2')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #3', y = 'Position (m) Run #3')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #4', y = 'Position (m) Run #4')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #5', y = 'Position (m) Run #5')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #6', y = 'Position (m) Run #6')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #7', y = 'Position (m) Run #7')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #8', y = 'Position (m) Run #8')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #9', y = 'Position (m) Run #9')
multiples_df.plot(kind = 'line', x = 'Time (s) Run #10', y = 'Position (m) Run #10')
# Out:
# <Axes: xlabel='Time (s) Run #10'>
