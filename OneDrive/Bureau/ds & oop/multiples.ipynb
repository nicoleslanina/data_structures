# %%
import pandas as pd
import matplotlib.pyplot as plt

multiples_df = pd.read_csv('new_white_filters_-_multiples.csv')
multiples_df
# Out:
#      Time (s) Run #1  Position (m) Run #1  Velocity (m/s) Run #1  \
# 0               0.00                 1.54                    NaN
# 1               0.02                 1.54                0.00000
# 2               0.04                 1.54                0.00000
# 3               0.06                 1.54                0.00032
# 4               0.08                 1.54                0.00000
# ..               ...                  ...                    ...
# 182              NaN                  NaN                    NaN
# 183              NaN                  NaN                    NaN
# 184              NaN                  NaN                    NaN
# 185              NaN                  NaN                    NaN
# 186              NaN                  NaN                    NaN
#
#      Acceleration (m/s²) Run #1  Time (s) Run #2  Position (m) Run #2  \
# 0                           NaN             0.00                 1.45
# ...
