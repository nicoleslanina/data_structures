# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

grades_df = pd.read_csv('Student_Grades.csv')
grades_df
# Out:
#          Hours    Practice    TeamWork     MidTerm   FinalExam      Scores  \
# 0          2.5         0.5         0.0         2.0         2.3        21.0
# 1          5.1         1.5         0.5         4.0         4.9        47.0
# 2          3.2         1.0         0.5         3.0         2.9        27.0
# 3          8.5         3.7         1.2         7.0         7.7        75.0
# 4          3.5         1.2         0.3         3.0         3.2        30.0
# 5          1.5         0.2         0.0         2.0         2.2        20.0
# 6          9.2         4.8         3.0         8.0         9.0        88.0
# 7          5.5         3.2         2.0         6.0         6.2        60.0
# 8          8.3         5.1         3.5         8.0         8.3        81.0
# 9          2.7         1.5         0.0         3.0         2.7        25.0
# 10         7.7         4.9         4.5         8.0         8.7        85.0
# 11         5.9         3.1         2.1         6.0         6.4        62.0
# 12         4.5         2.8         1.0         4.0         4.3        41.0
# 13         3.3         2.2         1.1         4.0         4.4        42.0
# 14         1.1         1.1         0.0         2.0         1.9        17.0
# 15         8.9         6.2         6.0         9.0         9.7        95.0
# 16         2.5         1.6         1.0         3.0         3.2        30.0
# 17         1.9         0.9         0.5         2.0         2.6        24.0
# 18         6.1         2.0         3.2         6.0         6.9        67.0
# 19         7.4         2.5         3.0         7.0         7.1        69.0
# 20         2.7         3.0         1.2         3.0         3.2        30.0
# 21         4.8         2.9         2.1         5.0         5.6        54.0
# 22         3.8         2.2         0.3         3.0         3.7        35.0
# 23         6.9         5.1         3.8         7.0         7.8        76.0
# 24         7.8         5.8         4.5         8.0         8.8        86.0
# 25  some value  some value  some value  some value  some value  some value
#
#          Grade
# 0            C
# 1            B
# 2            C
# 3            A
# 4            C
# 5            C
# 6            A
# 7            B
# 8            A
# 9            C
# 10           A
# 11           A
# 12           B
# 13           B
# 14           C
# 15           A
# 16           C
# 17           C
# 18           A
# 19           A
# 20           C
# 21           B
# 22           B
# 23           A
# 24           A
# 25  some value

# %%
# grades_df.replace(np.nan, 'some value', inplace = True)
# grades_df.to_csv('Student_Grades.csv', index = False)
# grades_df

# %%
grades_df.plot(kind = 'scatter', x = 'Hours', y = 'Scores')
# Out:
# <Axes: xlabel='Hours', ylabel='Scores'>

# %%
# explicit extraction
grades_df[grades_df['Grade'].str.contains('A')]
# Out:
#    Hours Practice TeamWork MidTerm FinalExam Scores Grade
# 3    8.5      3.7      1.2     7.0       7.7   75.0     A
# 6    9.2      4.8      3.0     8.0       9.0   88.0     A
# 8    8.3      5.1      3.5     8.0       8.3   81.0     A
# 10   7.7      4.9      4.5     8.0       8.7   85.0     A
# 11   5.9      3.1      2.1     6.0       6.4   62.0     A
# 15   8.9      6.2      6.0     9.0       9.7   95.0     A
# 18   6.1      2.0      3.2     6.0       6.9   67.0     A
# 19   7.4      2.5      3.0     7.0       7.1   69.0     A
# 23   6.9      5.1      3.8     7.0       7.8   76.0     A
# 24   7.8      5.8      4.5     8.0       8.8   86.0     A

# %%
grades_df['Scores'].min()
grades_df['Scores'].describe()
# Out:
# count       26
# unique      24
# top       30.0
# freq         3
# Name: Scores, dtype: object

# %% [markdown]
# - change numerical values to str
# - set index to hours

# %%
 # grades_df['Hours'] = grades_df['Hours'].astype(str)

new_df = grades_df.set_index('Hours').sort_values('Hours')
new_df

new_df.loc['1.1']

new_df.loc['1.1':'5.5']

new_df2 = grades_df.rename(columns = {'Hours': 'HOurs studied'})
new_df2 = new_df.rename_axis('Hours studied')
new_df2
# Out:
#                  Practice    TeamWork     MidTerm   FinalExam      Scores  \
# Hours studied
# 1.1                   1.1         0.0         2.0         1.9        17.0
# 1.5                   0.2         0.0         2.0         2.2        20.0
# 1.9                   0.9         0.5         2.0         2.6        24.0
# 2.5                   0.5         0.0         2.0         2.3        21.0
# 2.5                   1.6         1.0         3.0         3.2        30.0
# 2.7                   3.0         1.2         3.0         3.2        30.0
# 2.7                   1.5         0.0         3.0         2.7        25.0
# 3.2                   1.0         0.5         3.0         2.9        27.0
# 3.3                   2.2         1.1         4.0         4.4        42.0
# 3.5                   1.2         0.3         3.0         3.2        30.0
# 3.8                   2.2         0.3         3.0         3.7        35.0
# 4.5                   2.8         1.0         4.0         4.3        41.0
# 4.8                   2.9         2.1         5.0         5.6        54.0
# 5.1                   1.5         0.5         4.0         4.9        47.0
# 5.5                   3.2         2.0         6.0         6.2        60.0
# 5.9                   3.1         2.1         6.0         6.4        62.0
# 6.1                   2.0         3.2         6.0         6.9        67.0
# 6.9                   5.1         3.8         7.0         7.8        76.0
# 7.4                   2.5         3.0         7.0         7.1        69.0
# 7.7                   4.9         4.5         8.0         8.7        85.0
# 7.8                   5.8         4.5         8.0         8.8        86.0
# 8.3                   5.1         3.5         8.0         8.3        81.0
# 8.5                   3.7         1.2         7.0         7.7        75.0
# 8.9                   6.2         6.0         9.0         9.7        95.0
# 9.2                   4.8         3.0         8.0         9.0        88.0
# some value     some value  some value  some value  some value  some value
#
#                     Grade
# Hours studied
# 1.1                     C
# 1.5                     C
# 1.9                     C
# 2.5                     C
# 2.5                     C
# 2.7                     C
# 2.7                     C
# 3.2                     C
# 3.3                     B
# 3.5                     C
# 3.8                     B
# 4.5                     B
# 4.8                     B
# 5.1                     B
# 5.5                     B
# 5.9                     A
# 6.1                     A
# 6.9                     A
# 7.4                     A
# 7.7                     A
# 7.8                     A
# 8.3                     A
# 8.5                     A
# 8.9                     A
# 9.2                     A
# some value     some value

# %% [markdown]
# # loc and iloc

# %%
# get index of rows where 'Hours' column is equal to 1.1

lst = grades_df.index[grades_df['Hours'] == '2.5'].tolist()
print(lst)
index = lst[1]

grades_df.iloc[index]
grades_df.iloc[index:index+6]
# Out:
# [0, 16]
#    Hours Practice TeamWork MidTerm FinalExam Scores Grade
# 16   2.5      1.6      1.0     3.0       3.2   30.0     C
# 17   1.9      0.9      0.5     2.0       2.6   24.0     C
# 18   6.1      2.0      3.2     6.0       6.9   67.0     A
# 19   7.4      2.5      3.0     7.0       7.1   69.0     A
# 20   2.7      3.0      1.2     3.0       3.2   30.0     C
# 21   4.8      2.9      2.1     5.0       5.6   54.0     B

# %% [markdown]
# # at, iat

# %%
# new_df.loc[1.1:2, ['MidTerm', 'FinalExam', 'Scores']]

grades_df.iloc[[0,5], 0:4]

new_df.at['1.1', 'FinalExam']
grades_df.iat[2,4]
# Out:
# '2.9'

# %% [markdown]
# write a snippet of code that returns the minimum value in the 'Scores' column.

# %% [markdown]
# # Regression Fit

# %%
plt.scatter(xpoints, ypoints, s = 8)
plt.xlabel('hours spent studying')
plt.ylabel('Score')
plt.xlim(5, 9)
plt.ylim(0,100)

coeff = np.polyfit(xpoints, ypoints, deg =1)
best_fit_function = np.poly1d(coeff)
plt.plot(xpoints, best_fit_function(xpoints), label = 'Regression Fit', color = 'red')
plt.legend()
plst.show()
print(coeff)


b, a = np.polyfit(xpoints, ypoints, deg = 1) # b slope, a y-intercept
xseq = np.linspace(0,10)
plt.plot(xseq, b*xseq + a, c = 'red')

print(f'slope is {b}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 plt.scatter(xpoints, ypoints, s = 8)
#
# NameError: name 'xpoints' is not defined
